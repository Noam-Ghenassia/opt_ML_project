# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from utils import figure_8
from utils import net
from utils import test_performance_ADAM_ASAM_SAM
from utils import plot_dataset

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %% [markdown]
# ##### In this notebook, we will train our NN one dataset with a fixed mean and variance. After that, we test our model with other datasets with different variances. The aim of this experiment is to study the error on different datasets.

# %%
test_performance_ADAM_ASAM_SAM(2000, 1, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...

# %%
test_performance_ADAM_ASAM_SAM(2000, 5, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...

# %%
test_performance_ADAM_ASAM_SAM(2000, 10, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...

# %%
test_performance_ADAM_ASAM_SAM(2000, 15, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...

# %%
test_performance_ADAM_ASAM_SAM(2000, 25, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...

# %%
test_performance_ADAM_ASAM_SAM(2000, 30, 200)
# Out:
# training ADAM...
# training ASAM...
# training SAM...
